# %%
# obtain distance_to_edge file

data <- read.csv(file = "distance_to_edge.csv")
data
# Out:
#     ChrI.213 ChrX.227 ChrX.227.male
# 1     0      322       232
# 2     0      343       428
# 3     0      380       474
# 4    43      411       569
# 5    47      440       666
# 6    48      459       750
# 7    51      468       791
# 8    55      478       811
# 9    56      519       883
# 10   65      561       894
# 11   65      577       921
# 12   82      583       925
# 13   84      621       947
# 14   95      631       953
# 15  112      649       958
# 16  115      694       966
# 17  124      714      1022
# 18  147      730      1030
# 19  154      732      1035
# 20  161      749      1054
# 21  164      752      1074
# 22  167      766      1079
# 23  177      798      1090
# 24  210      814      1091
# 25  221      827      1093
# 26  280      869      1099
# 27  291      884      1100
# 28  301      900      1104
# 29  306      900      1105
# 30  339      903      1114
# ... ...      ...      ...
# 35   401      946     1222
# 36   402      970     1252
# ...

# %%
# convert ChrX.227 and ChrX.227.male columns into numeric values

chrX_227_numeric <- as.numeric(data$ChrX.227)
chrX_227_male_numeric <- as.numeric(data$ChrX.227.male)

chrX_227_numeric
chrX_227_male_numeric
# Out:
#  [1]  322  343  380  411  440  459  468  478  519  561  577  583  621  631  649
# [16]  694  714  730  732  749  752  766  798  814  827  869  884  900  900  903
# [31]  905  922  928  940  946  970  975  991  997 1016 1018 1037 1040 1061 1067
# [46] 1097 1113 1121 1142 1168 1180 1241 1261 1268 1268 1347 1388 1420 1421 1444
# [61] 1488 1544 1546 1662
#  [1]  232  428  474  569  666  750  791  811  883  894  921  925  947  953  958
# [16]  966 1022 1030 1035 1054 1074 1079 1090 1091 1093 1099 1100 1104 1105 1114
# [31] 1145 1148 1164 1176 1222 1252 1254 1267 1269 1272 1274 1294 1294 1311 1334
# [46] 1340 1341 1343 1360 1387 1395 1396 1402 1414 1477 1520 1535 1551 1556 1619
# [61]   NA   NA   NA   NA

# %%
# run the Kolmogorov-Smirnov test to test whether the cumulative distributions between ChrX 227 and ChrX 227 male are
# different

ks.test(chrX_227_numeric, chrX_227_male_numeric)
# Out:
# Warning message in ks.test(chrX_227_numeric, chrX_227_male_numeric):
# “cannot compute exact p-value with ties”
# 	Two-sample Kolmogorov-Smirnov test
#
# data:  chrX_227_numeric and chrX_227_male_numeric
# D = 0.37396, p-value = 0.0003463
# alternative hypothesis: two-sided
