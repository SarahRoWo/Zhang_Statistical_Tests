# %%
# obtain distance_to_edge file

data <- read.csv(file = "distance_to_edge.csv")
data
# Out:
#     ChrI.213 ChrX.227 ChrX.227.male
# 1     0      322       232
# 2     0      343       428
# 3     0      380       474
# 4    43      411       569
# 5    47      440       666
# 6    48      459       750
# 7    51      468       791
# 8    55      478       811
# 9    56      519       883
# 10   65      561       894
# 11   65      577       921
# 12   82      583       925
# 13   84      621       947
# 14   95      631       953
# 15  112      649       958
# 16  115      694       966
# 17  124      714      1022
# 18  147      730      1030
# 19  154      732      1035
# 20  161      749      1054
# 21  164      752      1074
# 22  167      766      1079
# 23  177      798      1090
# 24  210      814      1091
# 25  221      827      1093
# 26  280      869      1099
# 27  291      884      1100
# 28  301      900      1104
# 29  306      900      1105
# 30  339      903      1114
# ... ...      ...      ...
# 35   401      946     1222
# 36   402      970     1252
# ...

# %%
# compare ChrX 227 and ChrX 227 male using Welch's two sample t-test

t_test_result <- t.test(data[2], data[3])
print(t_test_result)
# Out:
# 	Welch Two Sample t-test
#
# data:  data[2] and data[3]
# t = -3.5816, df = 121.32, p-value = 0.0004924
# alternative hypothesis: true difference in means is not equal to 0
# 95 percent confidence interval:
#  -307.36339  -88.53244
# sample estimates:
# mean of x mean of y
#  928.2188 1126.1667
